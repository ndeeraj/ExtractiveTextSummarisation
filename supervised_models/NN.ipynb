# %% [markdown]
# # Feed forward neural network
#
# This notebook can be run from top to bottom after setting up the generated files as explained in the readme document at the project root directory.

# %%
import numpy as np
import os.path
from gensim.models import KeyedVectors
import time
import string
import train_embeddings_bbc
import preprocessing_bbc
import prepare_bbc_data
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.initializers import RandomNormal
from keras.regularizers import L2
from utils import create_inf_sents, featurize_X_from_text, featurize_embed_from_df

# %%
# load preprocessed files
train_file = preprocessing_bbc.cleaned_train_f
test_file = preprocessing_bbc.cleaned_test_f
val_file = preprocessing_bbc.cleaned_val_f

wv_from_text = train_embeddings_bbc.load_embeddings(train_embeddings_bbc.embedding_file)

train_data = pd.read_csv(train_file)
test_data = pd.read_csv(test_file)
val_data = pd.read_csv(val_file)

# %%
EMBED_SIZE = train_embeddings_bbc.EMBEDDINGS_SIZE

MAX_WORD_SIZE = preprocessing_bbc.MAX_THRESH

# %%
# initialize features with zeros
train_X = np.zeros((len(train_data), (EMBED_SIZE * MAX_WORD_SIZE)))
test_X = np.zeros((len(test_data), (EMBED_SIZE * MAX_WORD_SIZE)))
val_X = np.zeros((len(val_data), (EMBED_SIZE * MAX_WORD_SIZE)))

train_Y = np.zeros((len(train_data), 1))
test_Y = np.zeros((len(test_data), 1))
val_Y = np.zeros((len(val_data), 1))

# %%
# fill the features based on the learned embeddings
featurize_embed_from_df(train_data, train_X, train_Y, wv_from_text)
featurize_embed_from_df(test_data, test_X, test_Y, wv_from_text)
featurize_embed_from_df(val_data, val_X, val_Y, wv_from_text)

# %%
print("Shape of train X:")
print(train_X.shape)
print("Shape of train Y:")
print(train_Y.shape)

print("Shape of test X:")
print(test_X.shape)
print("Shape of test Y:")
print(test_Y.shape)

print("Shape of val X:")
print(val_X.shape)
print("Shape of val Y:")
print(val_Y.shape)
# Out:
# Shape of train X:
# (32722, 3250)
# Shape of train Y:
# (32722, 1)
# Shape of test X:
# (3872, 3250)
# Shape of test Y:
# (3872, 1)
# Shape of val X:
# (4725, 3250)
# Shape of val Y:
# (4725, 1)

# %%
# Define the model architecture using Keras Sequential API
class NNModel:
    '''
    Initizializes a model with number of hidden layers as specified in the hidden_dim list
    with activation functions as softmax at the final layer and relu for other layers.
    
    Uses Adam optimizer and binary cross entropy loss.
    '''
    def __init__(self, hidden_dim, feature_dim):
        '''
        Parameters:
            hidden_dim (list): each item specified the number of nodes in each hidden layer
            feature_dim (int): number of features in a sample
        '''
        
        if feature_dim <= 0 or feature_dim is None:
            raise Exception("feature dim mut be specified.")
        output_size = 1
        model = Sequential()
        for dim in hidden_dim:
            model.add(Dense(dim, input_dim=feature_dim, 
                            activation='relu',
                            kernel_initializer=RandomNormal(stddev=0.01),
                            kernel_regularizer=L2(0.5),
                           ))
    
        model.add(Dense(output_size, 
                        activation="softmax",
                        kernel_initializer=RandomNormal(stddev=0.01),
                        kernel_regularizer=L2(0.5),
                       ))
        self.model = model
        print(model.summary())
    
    def train(self, trainX, trainY, valX, valY, num_epochs=10, b_size=200, optim=None):
        '''
        trains the model with the provided parameters
        '''
        model = self.model
        if optim is None:
            optim = Adam(learning_rate=0.2)
        model.compile(loss="binary_crossentropy", optimizer=optim, metrics=["accuracy"])
        history = model.fit(trainX, trainY, batch_size=b_size, epochs=num_epochs, verbose=1, validation_data=(valX, valY), shuffle=True, validation_batch_size=b_size)
        return history
    
    def test_batch(self, testX):
        '''
        gets predictions for a batch of results.
        '''
        model = self.model
        predictions = model.predict(testX)
        return predictions
    
    def test_single(self, testX):
        '''
        gets prediction for a single instance
        '''
        model = self.model
        predictions = model([np.array(testX).reshape(1,-1)], training=False).numpy()
        return predictions

# %%
# variables to tune hyper parameters
best_model = None
best_val_avg_acc = -1
best_val_avg_loss = 999999999

# %%
# hyper parameters 1
b_size = 300
num_epochs = 50
model1 = NNModel([64, 32], train_X.shape[1])
moldel1_H = model1.train(train_X, train_Y, val_X, val_Y, num_epochs=num_epochs, b_size=b_size)

avg_acc = sum(moldel1_H.history['val_accuracy']) / len(moldel1_H.history['val_accuracy'])
avg_loss = sum(moldel1_H.history['val_loss']) / len(moldel1_H.history['val_loss'])

if avg_acc > best_val_avg_acc:
    print("selected the trained model as best model")
    print("average val accuracy: " + str(avg_acc))
    print("average val loss: " + str(avg_loss))
    best_model = model1
    best_val_avg_acc = avg_acc
    best_val_avg_loss = avg_loss
elif avg_acc == best_val_avg_acc:
    if avg_loss < best_val_avg_loss:
        print("selected the trained model as best model")
        print("average val accuracy: " + str(avg_acc))
        print("average val loss: " + str(avg_loss))
        best_model = model1
        best_val_avg_acc = avg_acc
        best_val_avg_loss = avg_loss
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                208064
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 210,177
# Trainable params: 210,177
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 110/110 [==============================] - 1s 5ms/step - loss: 149.2628 - accuracy: 0.4201 - val_loss: 0.6997 - val_accuracy: 0.4210
# Epoch 2/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6830 - accuracy: 0.4201 - val_loss: 0.6824 - val_accuracy: 0.4210
# Epoch 3/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6826 - accuracy: 0.4201 - val_loss: 0.6810 - val_accuracy: 0.4210
# Epoch 4/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6817 - accuracy: 0.4201 - val_loss: 0.6807 - val_accuracy: 0.4210
# Epoch 5/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6812 - accuracy: 0.4201 - val_loss: 0.6807 - val_accuracy: 0.4210
# Epoch 6/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.4201 - val_loss: 0.6839 - val_accuracy: 0.4210
# Epoch 7/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6812 - accuracy: 0.4201 - val_loss: 0.6814 - val_accuracy: 0.4210
# Epoch 8/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6815 - accuracy: 0.4201 - val_loss: 0.6823 - val_accuracy: 0.4210
# Epoch 9/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6834 - accuracy: 0.4201 - val_loss: 0.6884 - val_accuracy: 0.4210
# Epoch 10/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6831 - accuracy: 0.4201 - val_loss: 0.6856 - val_accuracy: 0.4210
# Epoch 11/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6841 - accuracy: 0.4201 - val_loss: 0.6825 - val_accuracy: 0.4210
# Epoch 12/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6832 - accuracy: 0.4201 - val_loss: 0.6857 - val_accuracy: 0.4210
# Epoch 13/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6848 - accuracy: 0.4201 - val_loss: 0.6904 - val_accuracy: 0.4210
# Epoch 14/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6894 - accuracy: 0.4201 - val_loss: 0.6980 - val_accuracy: 0.4210
# Epoch 15/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6933 - accuracy: 0.4201 - val_loss: 0.6966 - val_accuracy: 0.4210
# Epoch 16/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.7139 - accuracy: 0.4201 - val_loss: 0.7568 - val_accuracy: 0.4210
# Epoch 17/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.9096 - accuracy: 0.4201 - val_loss: 1.2946 - val_accuracy: 0.4210
# Epoch 18/50
# 110/110 [==============================] - 0s 4ms/step - loss: 2.9304 - accuracy: 0.4201 - val_loss: 5.3738 - val_accuracy: 0.4210
# Epoch 19/50
# 110/110 [==============================] - 0s 4ms/step - loss: 11.3097 - accuracy: 0.4201 - val_loss: 16.4465 - val_accuracy: 0.4210
# Epoch 20/50
# 110/110 [==============================] - 0s 4ms/step - loss: 13.2045 - accuracy: 0.4201 - val_loss: 1.3107 - val_accuracy: 0.4210
# Epoch 21/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.8751 - accuracy: 0.4201 - val_loss: 0.8176 - val_accuracy: 0.4210
# Epoch 22/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.8080 - accuracy: 0.4201 - val_loss: 0.8220 - val_accuracy: 0.4210
# Epoch 23/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.1389 - accuracy: 0.4201 - val_loss: 1.7606 - val_accuracy: 0.4210
# Epoch 24/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.7824 - accuracy: 0.4201 - val_loss: 1.7312 - val_accuracy: 0.4210
# Epoch 25/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.7259 - accuracy: 0.4201 - val_loss: 1.7585 - val_accuracy: 0.4210
# Epoch 26/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.8105 - accuracy: 0.4201 - val_loss: 1.8698 - val_accuracy: 0.4210
# Epoch 27/50
# 110/110 [==============================] - 1s 5ms/step - loss: 2.0081 - accuracy: 0.4201 - val_loss: 2.4445 - val_accuracy: 0.4210
# Epoch 28/50
# 110/110 [==============================] - 0s 4ms/step - loss: 3.6615 - accuracy: 0.4201 - val_loss: 6.3142 - val_accuracy: 0.4210
# Epoch 29/50
# 110/110 [==============================] - 0s 4ms/step - loss: 9.8279 - accuracy: 0.4201 - val_loss: 13.5212 - val_accuracy: 0.4210
# Epoch 30/50
# 110/110 [==============================] - 0s 4ms/step - loss: 8.6701 - accuracy: 0.4201 - val_loss: 2.0341 - val_accuracy: 0.4210
# Epoch 31/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.7772 - accuracy: 0.4201 - val_loss: 1.5707 - val_accuracy: 0.4210
# Epoch 32/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.6151 - accuracy: 0.4201 - val_loss: 1.5856 - val_accuracy: 0.4210
# Epoch 33/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.5560 - accuracy: 0.4201 - val_loss: 1.4684 - val_accuracy: 0.4210
# Epoch 34/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.6016 - accuracy: 0.4201 - val_loss: 1.4674 - val_accuracy: 0.4210
# Epoch 35/50
# 110/110 [==============================] - 0s 5ms/step - loss: 1.9118 - accuracy: 0.4201 - val_loss: 2.4726 - val_accuracy: 0.4210
# Epoch 36/50
# 110/110 [==============================] - 0s 4ms/step - loss: 4.6685 - accuracy: 0.4201 - val_loss: 7.4706 - val_accuracy: 0.4210
# Epoch 37/50
# 110/110 [==============================] - 0s 4ms/step - loss: 9.5717 - accuracy: 0.4201 - val_loss: 8.5976 - val_accuracy: 0.4210
# Epoch 38/50
# 110/110 [==============================] - 0s 4ms/step - loss: 3.0291 - accuracy: 0.4201 - val_loss: 1.3932 - val_accuracy: 0.4210
# Epoch 39/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.2233 - accuracy: 0.4201 - val_loss: 1.4211 - val_accuracy: 0.4210
# Epoch 40/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.1868 - accuracy: 0.4201 - val_loss: 1.2323 - val_accuracy: 0.4210
# Epoch 41/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.3938 - accuracy: 0.4201 - val_loss: 1.5700 - val_accuracy: 0.4210
# Epoch 42/50
# 110/110 [==============================] - 0s 4ms/step - loss: 2.6073 - accuracy: 0.4201 - val_loss: 4.6150 - val_accuracy: 0.4210
# Epoch 43/50
# 110/110 [==============================] - 0s 4ms/step - loss: 6.7618 - accuracy: 0.4201 - val_loss: 8.4304 - val_accuracy: 0.4210
# Epoch 44/50
# 110/110 [==============================] - 0s 4ms/step - loss: 5.4466 - accuracy: 0.4201 - val_loss: 1.7923 - val_accuracy: 0.4210
# Epoch 45/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.1980 - accuracy: 0.4201 - val_loss: 1.4508 - val_accuracy: 0.4210
# Epoch 46/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.0966 - accuracy: 0.4201 - val_loss: 1.0813 - val_accuracy: 0.4210
# Epoch 47/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.3223 - accuracy: 0.4201 - val_loss: 1.9324 - val_accuracy: 0.4210
# Epoch 48/50
# 110/110 [==============================] - 0s 4ms/step - loss: 3.1702 - accuracy: 0.4201 - val_loss: 5.0815 - val_accuracy: 0.4210
# Epoch 49/50
# 110/110 [==============================] - 1s 5ms/step - loss: 6.8321 - accuracy: 0.4201 - val_loss: 6.3795 - val_accuracy: 0.4210
# Epoch 50/50
# 110/110 [==============================] - 0s 4ms/step - loss: 3.0423 - accuracy: 0.4201 - val_loss: 1.1245 - val_accuracy: 0.4210
# selected the trained model as best model
# average val accuracy: 0.42095237970352173
# average val loss: 2.6138451075553895

# %%
# hyper parameters 2
b_size = 100
num_epochs = 100
model1 = NNModel([128, 32], train_X.shape[1])
moldel1_H = model1.train(train_X, train_Y, val_X, val_Y, num_epochs=num_epochs, b_size=b_size)

avg_acc = sum(moldel1_H.history['val_accuracy']) / len(moldel1_H.history['val_accuracy'])
avg_loss = sum(moldel1_H.history['val_loss']) / len(moldel1_H.history['val_loss'])

if avg_acc > best_val_avg_acc:
    print("selected the trained model as best model")
    print("average val accuracy: " + str(avg_acc))
    print("average val loss: " + str(avg_loss))
    best_model = model1
    best_val_avg_acc = avg_acc
    best_val_avg_loss = avg_loss
elif avg_acc == best_val_avg_acc:
    if avg_loss < best_val_avg_loss:
        print("selected the trained model as best model")
        print("average val accuracy: " + str(avg_acc))
        print("average val loss: " + str(avg_loss))
        best_model = model1
        best_val_avg_acc = avg_acc
        best_val_avg_loss = avg_loss
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 128)               416128
#
#  dense_4 (Dense)             (None, 32)                4128
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 420,289
# Trainable params: 420,289
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 328/328 [==============================] - 2s 4ms/step - loss: 99.7547 - accuracy: 0.4201 - val_loss: 0.6834 - val_accuracy: 0.4210
# Epoch 2/100
# 328/328 [==============================] - 1s 4ms/step - loss: 0.6818 - accuracy: 0.4201 - val_loss: 0.6821 - val_accuracy: 0.4210
# Epoch 3/100
# 328/328 [==============================] - 1s 4ms/step - loss: 0.6830 - accuracy: 0.4201 - val_loss: 0.6866 - val_accuracy: 0.4210
# Epoch 4/100
# 328/328 [==============================] - 1s 4ms/step - loss: 0.6869 - accuracy: 0.4201 - val_loss: 0.6891 - val_accuracy: 0.4210
# Epoch 5/100
# 328/328 [==============================] - 1s 3ms/step - loss: 0.7023 - accuracy: 0.4201 - val_loss: 0.7273 - val_accuracy: 0.4210
# Epoch 6/100
# 328/328 [==============================] - 1s 3ms/step - loss: 2.1605 - accuracy: 0.4201 - val_loss: 9.2102 - val_accuracy: 0.4210
# Epoch 7/100
# 328/328 [==============================] - 1s 3ms/step - loss: 17.7135 - accuracy: 0.4201 - val_loss: 0.9680 - val_accuracy: 0.4210
# Epoch 8/100
# 328/328 [==============================] - 1s 4ms/step - loss: 1.6050 - accuracy: 0.4201 - val_loss: 2.4660 - val_accuracy: 0.4210
# Epoch 9/100
# 328/328 [==============================] - 1s 3ms/step - loss: 2.8624 - accuracy: 0.4201 - val_loss: 3.4620 - val_accuracy: 0.4210
# Epoch 10/100
# 328/328 [==============================] - 1s 3ms/step - loss: 14.7504 - accuracy: 0.4201 - val_loss: 4.1081 - val_accuracy: 0.4210
# Epoch 11/100
# 328/328 [==============================] - 1s 3ms/step - loss: 2.5750 - accuracy: 0.4201 - val_loss: 2.4317 - val_accuracy: 0.4210
# Epoch 12/100
# 328/328 [==============================] - 1s 3ms/step - loss: 3.9509 - accuracy: 0.4201 - val_loss: 11.7709 - val_accuracy: 0.4210
# Epoch 13/100
# 328/328 [==============================] - 1s 4ms/step - loss: 9.8541 - accuracy: 0.4201 - val_loss: 2.0555 - val_accuracy: 0.4210
# Epoch 14/100
# 328/328 [==============================] - 1s 3ms/step - loss: 2.4328 - accuracy: 0.4201 - val_loss: 5.4786 - val_accuracy: 0.4210
# Epoch 15/100
# 328/328 [==============================] - 1s 3ms/step - loss: 9.1824 - accuracy: 0.4201 - val_loss: 1.9775 - val_accuracy: 0.4210
# Epoch 16/100
# 328/328 [==============================] - 1s 3ms/step - loss: 2.4657 - accuracy: 0.4201 - val_loss: 7.0351 - val_accuracy: 0.4210
# Epoch 17/100
# 328/328 [==============================] - 1s 3ms/step - loss: 7.6940 - accuracy: 0.4201 - val_loss: 1.2903 - val_accuracy: 0.4210
# Epoch 18/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.1128 - accuracy: 0.4201 - val_loss: 12.6686 - val_accuracy: 0.4210
# Epoch 19/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.1574 - accuracy: 0.4201 - val_loss: 1.4264 - val_accuracy: 0.4210
# Epoch 20/100
# 328/328 [==============================] - 1s 3ms/step - loss: 6.7992 - accuracy: 0.4201 - val_loss: 6.3161 - val_accuracy: 0.4210
# Epoch 21/100
# 328/328 [==============================] - 1s 3ms/step - loss: 46.9068 - accuracy: 0.4201 - val_loss: 5.7704 - val_accuracy: 0.4210
# Epoch 22/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.9999 - accuracy: 0.4201 - val_loss: 2.1324 - val_accuracy: 0.4210
# Epoch 23/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8304 - accuracy: 0.4201 - val_loss: 7.8707 - val_accuracy: 0.4210
# Epoch 24/100
# 328/328 [==============================] - 1s 3ms/step - loss: 3.8665 - accuracy: 0.4201 - val_loss: 4.0772 - val_accuracy: 0.4210
# Epoch 25/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.8902 - accuracy: 0.4201 - val_loss: 3.1005 - val_accuracy: 0.4210
# Epoch 26/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.6454 - accuracy: 0.4201 - val_loss: 7.1826 - val_accuracy: 0.4210
# Epoch 27/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.2883 - accuracy: 0.4201 - val_loss: 4.2770 - val_accuracy: 0.4210
# Epoch 28/100
# 328/328 [==============================] - 1s 4ms/step - loss: 5.5455 - accuracy: 0.4201 - val_loss: 3.5297 - val_accuracy: 0.4210
# Epoch 29/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.6919 - accuracy: 0.4201 - val_loss: 6.2263 - val_accuracy: 0.4210
# Epoch 30/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.3964 - accuracy: 0.4201 - val_loss: 4.7266 - val_accuracy: 0.4210
# Epoch 31/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.2796 - accuracy: 0.4201 - val_loss: 3.8069 - val_accuracy: 0.4210
# Epoch 32/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8467 - accuracy: 0.4201 - val_loss: 5.6093 - val_accuracy: 0.4210
# Epoch 33/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.4659 - accuracy: 0.4201 - val_loss: 5.0947 - val_accuracy: 0.4210
# Epoch 34/100
# 328/328 [==============================] - 1s 4ms/step - loss: 5.0631 - accuracy: 0.4201 - val_loss: 3.9579 - val_accuracy: 0.4210
# Epoch 35/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.9390 - accuracy: 0.4201 - val_loss: 5.0623 - val_accuracy: 0.4210
# Epoch 36/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.5503 - accuracy: 0.4201 - val_loss: 5.2291 - val_accuracy: 0.4210
# Epoch 37/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.9144 - accuracy: 0.4201 - val_loss: 4.2304 - val_accuracy: 0.4210
# Epoch 38/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.9716 - accuracy: 0.4201 - val_loss: 4.8744 - val_accuracy: 0.4210
# Epoch 39/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.6426 - accuracy: 0.4201 - val_loss: 5.2836 - val_accuracy: 0.4210
# Epoch 40/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8321 - accuracy: 0.4201 - val_loss: 4.4651 - val_accuracy: 0.4210
# Epoch 41/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.9502 - accuracy: 0.4201 - val_loss: 4.7770 - val_accuracy: 0.4210
# Epoch 42/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.7173 - accuracy: 0.4201 - val_loss: 5.1335 - val_accuracy: 0.4210
# Epoch 43/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.7855 - accuracy: 0.4201 - val_loss: 4.6874 - val_accuracy: 0.4210
# Epoch 44/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.9253 - accuracy: 0.4201 - val_loss: 4.7366 - val_accuracy: 0.4210
# Epoch 45/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.7643 - accuracy: 0.4201 - val_loss: 5.0354 - val_accuracy: 0.4210
# Epoch 46/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.7765 - accuracy: 0.4201 - val_loss: 4.7385 - val_accuracy: 0.4210
# Epoch 47/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8878 - accuracy: 0.4201 - val_loss: 4.7670 - val_accuracy: 0.4210
# Epoch 48/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8006 - accuracy: 0.4201 - val_loss: 4.8526 - val_accuracy: 0.4210
# Epoch 49/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.7799 - accuracy: 0.4201 - val_loss: 4.7815 - val_accuracy: 0.4210
# Epoch 50/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8625 - accuracy: 0.4201 - val_loss: 4.8032 - val_accuracy: 0.4210
# Epoch 51/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8145 - accuracy: 0.4201 - val_loss: 4.8286 - val_accuracy: 0.4210
# Epoch 52/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.7877 - accuracy: 0.4201 - val_loss: 4.8221 - val_accuracy: 0.4210
# Epoch 53/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8446 - accuracy: 0.4201 - val_loss: 4.7612 - val_accuracy: 0.4210
# Epoch 54/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8196 - accuracy: 0.4201 - val_loss: 4.8735 - val_accuracy: 0.4210
# Epoch 55/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.7968 - accuracy: 0.4201 - val_loss: 4.7869 - val_accuracy: 0.4210
# Epoch 56/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8334 - accuracy: 0.4201 - val_loss: 4.8226 - val_accuracy: 0.4210
# Epoch 57/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8250 - accuracy: 0.4201 - val_loss: 4.8513 - val_accuracy: 0.4210
# Epoch 58/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8027 - accuracy: 0.4201 - val_loss: 4.8505 - val_accuracy: 0.4210
# Epoch 59/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8240 - accuracy: 0.4201 - val_loss: 4.8205 - val_accuracy: 0.4210
# Epoch 60/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8273 - accuracy: 0.4201 - val_loss: 4.7733 - val_accuracy: 0.4210
# Epoch 61/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8086 - accuracy: 0.4201 - val_loss: 4.8455 - val_accuracy: 0.4210
# Epoch 62/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8174 - accuracy: 0.4201 - val_loss: 4.8421 - val_accuracy: 0.4210
# Epoch 63/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8241 - accuracy: 0.4201 - val_loss: 4.9347 - val_accuracy: 0.4210
# Epoch 64/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8126 - accuracy: 0.4201 - val_loss: 4.8708 - val_accuracy: 0.4210
# Epoch 65/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8166 - accuracy: 0.4201 - val_loss: 4.8372 - val_accuracy: 0.4210
# Epoch 66/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8252 - accuracy: 0.4201 - val_loss: 4.7940 - val_accuracy: 0.4210
# Epoch 67/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8080 - accuracy: 0.4201 - val_loss: 4.8006 - val_accuracy: 0.4210
# Epoch 68/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8281 - accuracy: 0.4201 - val_loss: 4.9233 - val_accuracy: 0.4210
# Epoch 69/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8183 - accuracy: 0.4201 - val_loss: 4.8023 - val_accuracy: 0.4210
# Epoch 70/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8121 - accuracy: 0.4201 - val_loss: 4.8976 - val_accuracy: 0.4210
# Epoch 71/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8195 - accuracy: 0.4201 - val_loss: 4.8639 - val_accuracy: 0.4210
# Epoch 72/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8256 - accuracy: 0.4201 - val_loss: 4.7983 - val_accuracy: 0.4210
# Epoch 73/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8154 - accuracy: 0.4201 - val_loss: 4.7735 - val_accuracy: 0.4210
# Epoch 74/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8120 - accuracy: 0.4201 - val_loss: 4.8034 - val_accuracy: 0.4210
# Epoch 75/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8233 - accuracy: 0.4201 - val_loss: 4.8199 - val_accuracy: 0.4210
# Epoch 76/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8204 - accuracy: 0.4201 - val_loss: 4.8721 - val_accuracy: 0.4210
# Epoch 77/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8157 - accuracy: 0.4201 - val_loss: 4.9294 - val_accuracy: 0.4210
# Epoch 78/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8183 - accuracy: 0.4201 - val_loss: 4.8845 - val_accuracy: 0.4210
# Epoch 79/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8188 - accuracy: 0.4201 - val_loss: 4.8666 - val_accuracy: 0.4210
# Epoch 80/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8188 - accuracy: 0.4201 - val_loss: 4.9617 - val_accuracy: 0.4210
# Epoch 81/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8212 - accuracy: 0.4201 - val_loss: 4.7954 - val_accuracy: 0.4210
# Epoch 82/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8186 - accuracy: 0.4201 - val_loss: 4.8290 - val_accuracy: 0.4210
# Epoch 83/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8174 - accuracy: 0.4201 - val_loss: 4.9355 - val_accuracy: 0.4210
# Epoch 84/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8147 - accuracy: 0.4201 - val_loss: 4.8381 - val_accuracy: 0.4210
# Epoch 85/100
# 328/328 [==============================] - 2s 5ms/step - loss: 4.8191 - accuracy: 0.4201 - val_loss: 4.8181 - val_accuracy: 0.4210
# Epoch 86/100
# 328/328 [==============================] - 2s 5ms/step - loss: 4.8201 - accuracy: 0.4201 - val_loss: 4.7988 - val_accuracy: 0.4210
# Epoch 87/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8155 - accuracy: 0.4201 - val_loss: 4.7706 - val_accuracy: 0.4210
# Epoch 88/100
# 328/328 [==============================] - 1s 5ms/step - loss: 4.8247 - accuracy: 0.4201 - val_loss: 4.8073 - val_accuracy: 0.4210
# Epoch 89/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8168 - accuracy: 0.4201 - val_loss: 4.7958 - val_accuracy: 0.4210
# Epoch 90/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8144 - accuracy: 0.4201 - val_loss: 4.7727 - val_accuracy: 0.4210
# Epoch 91/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8211 - accuracy: 0.4201 - val_loss: 4.8571 - val_accuracy: 0.4210
# Epoch 92/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8144 - accuracy: 0.4201 - val_loss: 4.8489 - val_accuracy: 0.4210
# Epoch 93/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8197 - accuracy: 0.4201 - val_loss: 4.7457 - val_accuracy: 0.4210
# Epoch 94/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8224 - accuracy: 0.4201 - val_loss: 4.8687 - val_accuracy: 0.4210
# Epoch 95/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8104 - accuracy: 0.4201 - val_loss: 4.9145 - val_accuracy: 0.4210
# Epoch 96/100
# 328/328 [==============================] - 2s 5ms/step - loss: 4.8206 - accuracy: 0.4201 - val_loss: 4.8320 - val_accuracy: 0.4210
# Epoch 97/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8274 - accuracy: 0.4201 - val_loss: 4.8358 - val_accuracy: 0.4210
# Epoch 98/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8106 - accuracy: 0.4201 - val_loss: 4.8728 - val_accuracy: 0.4210
# Epoch 99/100
# 328/328 [==============================] - 1s 5ms/step - loss: 4.8186 - accuracy: 0.4201 - val_loss: 4.8403 - val_accuracy: 0.4210
# Epoch 100/100
# 328/328 [==============================] - 1s 4ms/step - loss: 4.8246 - accuracy: 0.4201 - val_loss: 4.8266 - val_accuracy: 0.4210

# %%
# hyper parameters 3
b_size = 300
num_epochs = 50
model1 = NNModel([64, 32], train_X.shape[1])
moldel1_H = model1.train(train_X, train_Y, val_X, val_Y, num_epochs=num_epochs, b_size=b_size, optim=Adam(learning_rate=0.01))

avg_acc = sum(moldel1_H.history['val_accuracy']) / len(moldel1_H.history['val_accuracy'])
avg_loss = sum(moldel1_H.history['val_loss']) / len(moldel1_H.history['val_loss'])

if avg_acc > best_val_avg_acc:
    print("selected the trained model as best model")
    print("average val accuracy: " + str(avg_acc))
    print("average val loss: " + str(avg_loss))
    best_model = model1
    best_val_avg_acc = avg_acc
    best_val_avg_loss = avg_loss
elif avg_acc == best_val_avg_acc:
    if avg_loss < best_val_avg_loss:
        print("selected the trained model as best model")
        print("average val accuracy: " + str(avg_acc))
        print("average val loss: " + str(avg_loss))
        best_model = model1
        best_val_avg_acc = avg_acc
        best_val_avg_loss = avg_loss
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 64)                208064
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dense_8 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 210,177
# Trainable params: 210,177
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 110/110 [==============================] - 1s 8ms/step - loss: 1.1190 - accuracy: 0.4201 - val_loss: 0.6807 - val_accuracy: 0.4210
# Epoch 2/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6805 - accuracy: 0.4201 - val_loss: 0.6806 - val_accuracy: 0.4210
# Epoch 3/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6805 - accuracy: 0.4201 - val_loss: 0.6808 - val_accuracy: 0.4210
# Epoch 4/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6805 - accuracy: 0.4201 - val_loss: 0.6808 - val_accuracy: 0.4210
# Epoch 5/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6805 - accuracy: 0.4201 - val_loss: 0.6806 - val_accuracy: 0.4210
# Epoch 6/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6804 - accuracy: 0.4201 - val_loss: 0.6807 - val_accuracy: 0.4210
# Epoch 7/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6805 - accuracy: 0.4201 - val_loss: 0.6807 - val_accuracy: 0.4210
# Epoch 8/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6804 - accuracy: 0.4201 - val_loss: 0.6806 - val_accuracy: 0.4210
# Epoch 9/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6804 - accuracy: 0.4201 - val_loss: 0.6809 - val_accuracy: 0.4210
# Epoch 10/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6804 - accuracy: 0.4201 - val_loss: 0.6806 - val_accuracy: 0.4210
# Epoch 11/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6804 - accuracy: 0.4201 - val_loss: 0.6806 - val_accuracy: 0.4210
# Epoch 12/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6823 - accuracy: 0.4201 - val_loss: 0.6823 - val_accuracy: 0.4210
# Epoch 13/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6895 - accuracy: 0.4201 - val_loss: 0.6864 - val_accuracy: 0.4210
# Epoch 14/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6859 - accuracy: 0.4201 - val_loss: 0.6862 - val_accuracy: 0.4210
# Epoch 15/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6867 - accuracy: 0.4201 - val_loss: 0.6870 - val_accuracy: 0.4210
# Epoch 16/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6865 - accuracy: 0.4201 - val_loss: 0.6866 - val_accuracy: 0.4210
# Epoch 17/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6865 - accuracy: 0.4201 - val_loss: 0.6872 - val_accuracy: 0.4210
# Epoch 18/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6876 - accuracy: 0.4201 - val_loss: 0.6874 - val_accuracy: 0.4210
# Epoch 19/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6864 - accuracy: 0.4201 - val_loss: 0.6878 - val_accuracy: 0.4210
# Epoch 20/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6855 - accuracy: 0.4201 - val_loss: 0.6853 - val_accuracy: 0.4210
# Epoch 21/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6886 - accuracy: 0.4201 - val_loss: 0.6903 - val_accuracy: 0.4210
# Epoch 22/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6880 - accuracy: 0.4201 - val_loss: 0.6874 - val_accuracy: 0.4210
# Epoch 23/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6867 - accuracy: 0.4201 - val_loss: 0.6873 - val_accuracy: 0.4210
# Epoch 24/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6872 - accuracy: 0.4201 - val_loss: 0.6882 - val_accuracy: 0.4210
# Epoch 25/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6881 - accuracy: 0.4201 - val_loss: 0.6883 - val_accuracy: 0.4210
# Epoch 26/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6877 - accuracy: 0.4201 - val_loss: 0.6874 - val_accuracy: 0.4210
# Epoch 27/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6872 - accuracy: 0.4201 - val_loss: 0.6873 - val_accuracy: 0.4210
# Epoch 28/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6900 - accuracy: 0.4201 - val_loss: 0.6907 - val_accuracy: 0.4210
# Epoch 29/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6911 - accuracy: 0.4201 - val_loss: 0.6880 - val_accuracy: 0.4210
# Epoch 30/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6872 - accuracy: 0.4201 - val_loss: 0.6874 - val_accuracy: 0.4210
# Epoch 31/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6870 - accuracy: 0.4201 - val_loss: 0.6877 - val_accuracy: 0.4210
# Epoch 32/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6881 - accuracy: 0.4201 - val_loss: 0.6888 - val_accuracy: 0.4210
# Epoch 33/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6877 - accuracy: 0.4201 - val_loss: 0.6876 - val_accuracy: 0.4210
# Epoch 34/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6893 - accuracy: 0.4201 - val_loss: 0.6897 - val_accuracy: 0.4210
# Epoch 35/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6888 - accuracy: 0.4201 - val_loss: 0.6888 - val_accuracy: 0.4210
# Epoch 36/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6887 - accuracy: 0.4201 - val_loss: 0.6881 - val_accuracy: 0.4210
# Epoch 37/50
# 110/110 [==============================] - 1s 6ms/step - loss: 0.6870 - accuracy: 0.4201 - val_loss: 0.6869 - val_accuracy: 0.4210
# Epoch 38/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6871 - accuracy: 0.4201 - val_loss: 0.6877 - val_accuracy: 0.4210
# Epoch 39/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6885 - accuracy: 0.4201 - val_loss: 0.6902 - val_accuracy: 0.4210
# Epoch 40/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6892 - accuracy: 0.4201 - val_loss: 0.6887 - val_accuracy: 0.4210
# Epoch 41/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6882 - accuracy: 0.4201 - val_loss: 0.6882 - val_accuracy: 0.4210
# Epoch 42/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6877 - accuracy: 0.4201 - val_loss: 0.6878 - val_accuracy: 0.4210
# Epoch 43/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6873 - accuracy: 0.4201 - val_loss: 0.6874 - val_accuracy: 0.4210
# Epoch 44/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6882 - accuracy: 0.4201 - val_loss: 0.6894 - val_accuracy: 0.4210
# Epoch 45/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6889 - accuracy: 0.4201 - val_loss: 0.6883 - val_accuracy: 0.4210
# Epoch 46/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6875 - accuracy: 0.4201 - val_loss: 0.6878 - val_accuracy: 0.4210
# Epoch 47/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6880 - accuracy: 0.4201 - val_loss: 0.6880 - val_accuracy: 0.4210
# Epoch 48/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6880 - accuracy: 0.4201 - val_loss: 0.6887 - val_accuracy: 0.4210
# Epoch 49/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6887 - accuracy: 0.4201 - val_loss: 0.6881 - val_accuracy: 0.4210
# Epoch 50/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6874 - accuracy: 0.4201 - val_loss: 0.6879 - val_accuracy: 0.4210
# selected the trained model as best model
# average val accuracy: 0.42095237970352173
# average val loss: 0.6862332773208618

# %%
def accuracy(y, y_hat):
    """
    Citation: taken from lecture notebook
    
    Measure the accuracy of our model, print the results.
    Parameters:
        y (array): true labels
        y_hat (array): model estimates
    Returns:
        None
    """
    count = 0
    for i in range(len(y)):
        guess = 1 if y_hat[i] > 0.5 else 0
        if guess == y[i]:
            count += 1
    print("Accuracy:", round((count / y.shape[0]) * 100, 2))

# %%
pred = best_model.test_batch(test_X)
accuracy(test_Y, pred.reshape(test_Y.shape))
# Out:
# 121/121 [==============================] - 0s 792us/step
# Accuracy: 41.89

# %%
# create summaries for the test set using the trained model.
# original test data

inf_file = prepare_bbc_data.out_test_file
inf_df = pd.read_csv(inf_file)

out_headers = {'article': [],
               'original_summary': [],
               'model_summary': [],
              }

# summaries generated from the model will be written to this file.
out_file = 'NN_results.csv'

out_df = pd.DataFrame(out_headers)

inf_start = time.time()
for i in range(len(inf_df)):
    art_txt = inf_df.at[i, 'article'].strip()
    # from raw article text, create sentences. 
    # prepped sent has the preprocessed sentence while orig_sent has the actual sentence
    orig_sent, prepped_sent = create_inf_sents(art_txt)

    summary = []
    # loops to estimate if the sentence is a highlight or not 
    # If it is a highlight, appends the original sentence to the summary string.
    for j, sent in enumerate(prepped_sent):
        inf_X = featurize_X_from_text(sent, wv_from_text)
        pred = best_model.test_single(inf_X)
        if pred[0] > 0.5:
            summary.append(orig_sent[j])
    out_df.at[i, 'article'] = art_txt
    out_df.at[i, 'original_summary'] = inf_df.at[i, 'summary'].strip()
    if len(summary) == 0:
        out_df.at[i, 'model_summary'] = "__BLANK__"
    else:
        out_df.at[i, 'model_summary'] = " ".join(summary)

out_df.to_csv(out_file, index=False)
print("inference completed for the test set\nTime taken: " + str(time.time()-inf_start))
# Out:
# inference completed for the test set
# Time taken: 5.322991609573364
