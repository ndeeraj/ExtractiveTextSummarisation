# %%
import numpy as np
import os.path
from gensim.models import KeyedVectors
import time
import string
import train_embeddings_bbc
import preprocessing_bbc
import prepare_bbc_data
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.initializers import RandomNormal
from keras.regularizers import L2
from utils import create_inf_sents, featurize_X_from_text, featurize_embed_from_df

# %%
# load preprocessed files
train_file = preprocessing_bbc.cleaned_train_f
test_file = preprocessing_bbc.cleaned_test_f
val_file = preprocessing_bbc.cleaned_val_f

wv_from_text = train_embeddings_bbc.load_embeddings(train_embeddings_bbc.embedding_file)

train_data = pd.read_csv(train_file)
test_data = pd.read_csv(test_file)
val_data = pd.read_csv(val_file)

# %%
EMBED_SIZE = train_embeddings_bbc.EMBEDDINGS_SIZE

MAX_WORD_SIZE = preprocessing_bbc.MAX_THRESH

# %%
# initialize features with zeros
train_X = np.zeros((len(train_data), (EMBED_SIZE * MAX_WORD_SIZE)))
test_X = np.zeros((len(test_data), (EMBED_SIZE * MAX_WORD_SIZE)))
val_X = np.zeros((len(val_data), (EMBED_SIZE * MAX_WORD_SIZE)))

train_Y = np.zeros((len(train_data), 1))
test_Y = np.zeros((len(test_data), 1))
val_Y = np.zeros((len(val_data), 1))

# %%
# fill the features based on the learned embeddings
featurize_embed_from_df(train_data, train_X, train_Y, wv_from_text)
featurize_embed_from_df(test_data, test_X, test_Y, wv_from_text)
featurize_embed_from_df(val_data, val_X, val_Y, wv_from_text)

# %%
print("Shape of train X:")
print(train_X.shape)
print("Shape of train Y:")
print(train_Y.shape)

print("Shape of test X:")
print(test_X.shape)
print("Shape of test Y:")
print(test_Y.shape)

print("Shape of val X:")
print(val_X.shape)
print("Shape of val Y:")
print(val_Y.shape)
# Out:
# Shape of train X:
# (32722, 3250)
# Shape of train Y:
# (32722, 1)
# Shape of test X:
# (3872, 3250)
# Shape of test Y:
# (3872, 1)
# Shape of val X:
# (4725, 3250)
# Shape of val Y:
# (4725, 1)

# %%
# Define the model architecture using Keras Sequential API
class NNModel:
    '''
    Initizializes a model with number of hidden layers as specified in the hidden_dim list
    with activation functions as softmax at the final layer and relu for other layers.
    
    Uses Adam optimizer and binary cross entropy loss.
    '''
    def __init__(self, hidden_dim, feature_dim):
        '''
        Parameters:
            hidden_dim (list): each item specified the number of nodes in each hidden layer
            feature_dim (int): number of features in a sample
        '''
        
        if feature_dim <= 0 or feature_dim is None:
            raise Exception("feature dim mut be specified.")
        output_size = 1
        model = Sequential()
        for dim in hidden_dim:
            model.add(Dense(dim, input_dim=feature_dim, 
                            activation='relu',
                            kernel_initializer=RandomNormal(stddev=0.01),
                            kernel_regularizer=L2(0.5),
                           ))
    
        model.add(Dense(output_size, 
                        activation="softmax",
                        kernel_initializer=RandomNormal(stddev=0.01),
                        kernel_regularizer=L2(0.5),
                       ))
        self.model = model
        print(model.summary())
    
    def train(self, trainX, trainY, valX, valY, num_epochs=10, b_size=200, optim=None):
        '''
        trains the model with the provided parameters
        '''
        model = self.model
        if optim is None:
            optim = Adam(learning_rate=0.2)
        model.compile(loss="binary_crossentropy", optimizer=optim, metrics=["accuracy"])
        history = model.fit(trainX, trainY, batch_size=b_size, epochs=num_epochs, verbose=1, validation_data=(valX, valY), shuffle=True, validation_batch_size=b_size)
        return history
    
    def test_batch(self, testX):
        '''
        gets predictions for a batch of results.
        '''
        model = self.model
        predictions = model.predict(testX)
        return predictions
    
    def test_single(self, testX):
        '''
        gets prediction for a single instance
        '''
        model = self.model
        predictions = model([np.array(testX).reshape(1,-1)], training=False).numpy()
        return predictions

# %%
# variables to tune hyper parameters
best_model = None
best_val_avg_acc = -1
best_val_avg_loss = 999999999

# %%
# hyper parameters 1
b_size = 300
num_epochs = 50
model1 = NNModel([64, 32], train_X.shape[1])
moldel1_H = model1.train(train_X, train_Y, val_X, val_Y, num_epochs=num_epochs, b_size=b_size)

avg_acc = sum(moldel1_H.history['val_accuracy']) / len(moldel1_H.history['val_accuracy'])
avg_loss = sum(moldel1_H.history['val_loss']) / len(moldel1_H.history['val_loss'])

if avg_acc > best_val_avg_acc:
    print("selected the trained model as best model")
    print("average val accuracy: " + str(avg_acc))
    print("average val loss: " + str(avg_loss))
    best_model = model1
    best_val_avg_acc = avg_acc
    best_val_avg_loss = avg_loss
elif avg_acc == best_val_avg_acc:
    if avg_loss < best_val_avg_loss:
        print("selected the trained model as best model")
        print("average val accuracy: " + str(avg_acc))
        print("average val loss: " + str(avg_loss))
        best_model = model1
        best_val_avg_acc = avg_acc
        best_val_avg_loss = avg_loss
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                208064
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 210,177
# Trainable params: 210,177
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 110/110 [==============================] - 1s 6ms/step - loss: 149.2389 - accuracy: 0.4201 - val_loss: 0.6994 - val_accuracy: 0.4210
# Epoch 2/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6830 - accuracy: 0.4201 - val_loss: 0.6806 - val_accuracy: 0.4210
# Epoch 3/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6812 - accuracy: 0.4201 - val_loss: 0.6835 - val_accuracy: 0.4210
# Epoch 4/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6813 - accuracy: 0.4201 - val_loss: 0.6807 - val_accuracy: 0.4210
# Epoch 5/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6810 - accuracy: 0.4201 - val_loss: 0.6881 - val_accuracy: 0.4210
# Epoch 6/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6816 - accuracy: 0.4201 - val_loss: 0.6809 - val_accuracy: 0.4210
# Epoch 7/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6821 - accuracy: 0.4201 - val_loss: 0.6860 - val_accuracy: 0.4210
# Epoch 8/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6813 - accuracy: 0.4201 - val_loss: 0.6808 - val_accuracy: 0.4210
# Epoch 9/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6823 - accuracy: 0.4201 - val_loss: 0.6819 - val_accuracy: 0.4210
# Epoch 10/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6847 - accuracy: 0.4201 - val_loss: 0.6815 - val_accuracy: 0.4210
# Epoch 11/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6837 - accuracy: 0.4201 - val_loss: 0.6874 - val_accuracy: 0.4210
# Epoch 12/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6847 - accuracy: 0.4201 - val_loss: 0.6872 - val_accuracy: 0.4210
# Epoch 13/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6856 - accuracy: 0.4201 - val_loss: 0.6858 - val_accuracy: 0.4210
# Epoch 14/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6860 - accuracy: 0.4201 - val_loss: 0.6875 - val_accuracy: 0.4210
# Epoch 15/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6902 - accuracy: 0.4201 - val_loss: 0.6868 - val_accuracy: 0.4210
# Epoch 16/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.7026 - accuracy: 0.4201 - val_loss: 0.7206 - val_accuracy: 0.4210
# Epoch 17/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.8848 - accuracy: 0.4201 - val_loss: 1.2386 - val_accuracy: 0.4210
# Epoch 18/50
# 110/110 [==============================] - 1s 6ms/step - loss: 2.8714 - accuracy: 0.4201 - val_loss: 5.5655 - val_accuracy: 0.4210
# Epoch 19/50
# 110/110 [==============================] - 0s 4ms/step - loss: 11.3656 - accuracy: 0.4201 - val_loss: 16.4217 - val_accuracy: 0.4210
# Epoch 20/50
# 110/110 [==============================] - 0s 4ms/step - loss: 13.4296 - accuracy: 0.4201 - val_loss: 1.1250 - val_accuracy: 0.4210
# Epoch 21/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.8281 - accuracy: 0.4201 - val_loss: 0.7699 - val_accuracy: 0.4210
# Epoch 22/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.7948 - accuracy: 0.4201 - val_loss: 0.7972 - val_accuracy: 0.4210
# Epoch 23/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.1151 - accuracy: 0.4201 - val_loss: 1.7002 - val_accuracy: 0.4210
# Epoch 24/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.7534 - accuracy: 0.4201 - val_loss: 1.9227 - val_accuracy: 0.4210
# Epoch 25/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.7795 - accuracy: 0.4201 - val_loss: 1.6301 - val_accuracy: 0.4210
# Epoch 26/50
# 110/110 [==============================] - 1s 6ms/step - loss: 1.7690 - accuracy: 0.4201 - val_loss: 1.8280 - val_accuracy: 0.4210
# Epoch 27/50
# 110/110 [==============================] - 1s 6ms/step - loss: 2.0039 - accuracy: 0.4201 - val_loss: 2.3794 - val_accuracy: 0.4210
# Epoch 28/50
# 110/110 [==============================] - 1s 6ms/step - loss: 3.6764 - accuracy: 0.4201 - val_loss: 6.1196 - val_accuracy: 0.4210
# Epoch 29/50
# 110/110 [==============================] - 1s 5ms/step - loss: 9.8817 - accuracy: 0.4201 - val_loss: 13.5915 - val_accuracy: 0.4210
# Epoch 30/50
# 110/110 [==============================] - 1s 5ms/step - loss: 8.7930 - accuracy: 0.4201 - val_loss: 1.8821 - val_accuracy: 0.4210
# Epoch 31/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.7245 - accuracy: 0.4201 - val_loss: 1.5755 - val_accuracy: 0.4210
# Epoch 32/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.5797 - accuracy: 0.4201 - val_loss: 1.6668 - val_accuracy: 0.4210
# Epoch 33/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.5624 - accuracy: 0.4201 - val_loss: 1.5615 - val_accuracy: 0.4210
# Epoch 34/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.5805 - accuracy: 0.4201 - val_loss: 1.4707 - val_accuracy: 0.4210
# Epoch 35/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.9894 - accuracy: 0.4201 - val_loss: 2.4094 - val_accuracy: 0.4210
# Epoch 36/50
# 110/110 [==============================] - 0s 4ms/step - loss: 4.6635 - accuracy: 0.4201 - val_loss: 7.6331 - val_accuracy: 0.4210
# Epoch 37/50
# 110/110 [==============================] - 1s 5ms/step - loss: 9.6727 - accuracy: 0.4201 - val_loss: 8.9856 - val_accuracy: 0.4210
# Epoch 38/50
# 110/110 [==============================] - 0s 4ms/step - loss: 2.9712 - accuracy: 0.4201 - val_loss: 1.5469 - val_accuracy: 0.4210
# Epoch 39/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.2899 - accuracy: 0.4201 - val_loss: 1.2314 - val_accuracy: 0.4210
# Epoch 40/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.2715 - accuracy: 0.4201 - val_loss: 1.1019 - val_accuracy: 0.4210
# Epoch 41/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.4015 - accuracy: 0.4201 - val_loss: 1.6537 - val_accuracy: 0.4210
# Epoch 42/50
# 110/110 [==============================] - 0s 4ms/step - loss: 2.5998 - accuracy: 0.4201 - val_loss: 4.3993 - val_accuracy: 0.4210
# Epoch 43/50
# 110/110 [==============================] - 0s 4ms/step - loss: 6.8384 - accuracy: 0.4201 - val_loss: 8.6146 - val_accuracy: 0.4210
# Epoch 44/50
# 110/110 [==============================] - 0s 4ms/step - loss: 5.5843 - accuracy: 0.4201 - val_loss: 1.6948 - val_accuracy: 0.4210
# Epoch 45/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.1897 - accuracy: 0.4201 - val_loss: 1.0973 - val_accuracy: 0.4210
# Epoch 46/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.0088 - accuracy: 0.4201 - val_loss: 0.9898 - val_accuracy: 0.4210
# Epoch 47/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.3534 - accuracy: 0.4201 - val_loss: 1.7269 - val_accuracy: 0.4210
# Epoch 48/50
# 110/110 [==============================] - 0s 4ms/step - loss: 3.1792 - accuracy: 0.4201 - val_loss: 4.9759 - val_accuracy: 0.4210
# Epoch 49/50
# 110/110 [==============================] - 0s 4ms/step - loss: 6.8777 - accuracy: 0.4201 - val_loss: 6.5557 - val_accuracy: 0.4210
# Epoch 50/50
# 110/110 [==============================] - 0s 4ms/step - loss: 3.0419 - accuracy: 0.4201 - val_loss: 1.0545 - val_accuracy: 0.4210
# selected the trained model as best model
# average val accuracy: 0.42095237970352173
# average val loss: 2.5983110916614534

# %%
# hyper parameters 2
b_size = 100
num_epochs = 100
model1 = NNModel([128, 32], train_X.shape[1])
moldel1_H = model1.train(train_X, train_Y, val_X, val_Y, num_epochs=num_epochs, b_size=b_size)

avg_acc = sum(moldel1_H.history['val_accuracy']) / len(moldel1_H.history['val_accuracy'])
avg_loss = sum(moldel1_H.history['val_loss']) / len(moldel1_H.history['val_loss'])

if avg_acc > best_val_avg_acc:
    print("selected the trained model as best model")
    print("average val accuracy: " + str(avg_acc))
    print("average val loss: " + str(avg_loss))
    best_model = model1
    best_val_avg_acc = avg_acc
    best_val_avg_loss = avg_loss
elif avg_acc == best_val_avg_acc:
    if avg_loss < best_val_avg_loss:
        print("selected the trained model as best model")
        print("average val accuracy: " + str(avg_acc))
        print("average val loss: " + str(avg_loss))
        best_model = model1
        best_val_avg_acc = avg_acc
        best_val_avg_loss = avg_loss
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 128)               416128
#
#  dense_4 (Dense)             (None, 32)                4128
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 420,289
# Trainable params: 420,289
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 328/328 [==============================] - 1s 3ms/step - loss: 99.8758 - accuracy: 0.4201 - val_loss: 0.6808 - val_accuracy: 0.4210
# Epoch 2/100
# 328/328 [==============================] - 1s 3ms/step - loss: 0.6824 - accuracy: 0.4201 - val_loss: 0.6838 - val_accuracy: 0.4210
# Epoch 3/100
# 328/328 [==============================] - 1s 3ms/step - loss: 0.6827 - accuracy: 0.4201 - val_loss: 0.6934 - val_accuracy: 0.4210
# Epoch 4/100
# 328/328 [==============================] - 1s 3ms/step - loss: 0.6881 - accuracy: 0.4201 - val_loss: 0.6953 - val_accuracy: 0.4210
# Epoch 5/100
# 328/328 [==============================] - 1s 3ms/step - loss: 0.7158 - accuracy: 0.4201 - val_loss: 0.7654 - val_accuracy: 0.4210
# Epoch 6/100
# 328/328 [==============================] - 1s 3ms/step - loss: 2.2631 - accuracy: 0.4201 - val_loss: 9.0680 - val_accuracy: 0.4210
# Epoch 7/100
# 328/328 [==============================] - 1s 3ms/step - loss: 17.9268 - accuracy: 0.4201 - val_loss: 1.0637 - val_accuracy: 0.4210
# Epoch 8/100
# 328/328 [==============================] - 1s 3ms/step - loss: 1.5638 - accuracy: 0.4201 - val_loss: 2.5377 - val_accuracy: 0.4210
# Epoch 9/100
# 328/328 [==============================] - 1s 3ms/step - loss: 3.3971 - accuracy: 0.4201 - val_loss: 4.7310 - val_accuracy: 0.4210
# Epoch 10/100
# 328/328 [==============================] - 1s 3ms/step - loss: 13.9358 - accuracy: 0.4201 - val_loss: 4.2668 - val_accuracy: 0.4210
# Epoch 11/100
# 328/328 [==============================] - 1s 3ms/step - loss: 3.0985 - accuracy: 0.4201 - val_loss: 2.9452 - val_accuracy: 0.4210
# Epoch 12/100
# 328/328 [==============================] - 1s 3ms/step - loss: 7.2886 - accuracy: 0.4201 - val_loss: 10.0688 - val_accuracy: 0.4210
# Epoch 13/100
# 328/328 [==============================] - 1s 3ms/step - loss: 8.5124 - accuracy: 0.4201 - val_loss: 3.0090 - val_accuracy: 0.4210
# Epoch 14/100
# 328/328 [==============================] - 1s 3ms/step - loss: 3.6795 - accuracy: 0.4201 - val_loss: 6.2622 - val_accuracy: 0.4210
# Epoch 15/100
# 328/328 [==============================] - 1s 3ms/step - loss: 9.3701 - accuracy: 0.4201 - val_loss: 2.5469 - val_accuracy: 0.4210
# Epoch 16/100
# 328/328 [==============================] - 1s 3ms/step - loss: 3.5979 - accuracy: 0.4201 - val_loss: 6.9051 - val_accuracy: 0.4210
# Epoch 17/100
# 328/328 [==============================] - 1s 3ms/step - loss: 7.1450 - accuracy: 0.4201 - val_loss: 2.4961 - val_accuracy: 0.4210
# Epoch 18/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.7526 - accuracy: 0.4201 - val_loss: 10.8721 - val_accuracy: 0.4210
# Epoch 19/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.2087 - accuracy: 0.4201 - val_loss: 2.8005 - val_accuracy: 0.4210
# Epoch 20/100
# 328/328 [==============================] - 1s 3ms/step - loss: 6.5797 - accuracy: 0.4201 - val_loss: 5.8246 - val_accuracy: 0.4210
# Epoch 21/100
# 328/328 [==============================] - 1s 3ms/step - loss: 3.5544 - accuracy: 0.4201 - val_loss: 5.5491 - val_accuracy: 0.4210
# Epoch 22/100
# 328/328 [==============================] - 1s 3ms/step - loss: 6.2151 - accuracy: 0.4201 - val_loss: 2.7903 - val_accuracy: 0.4210
# Epoch 23/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.2664 - accuracy: 0.4201 - val_loss: 7.5937 - val_accuracy: 0.4210
# Epoch 24/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.2542 - accuracy: 0.4201 - val_loss: 4.4538 - val_accuracy: 0.4210
# Epoch 25/100
# 328/328 [==============================] - 1s 3ms/step - loss: 6.0221 - accuracy: 0.4201 - val_loss: 3.5560 - val_accuracy: 0.4210
# Epoch 26/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.9518 - accuracy: 0.4201 - val_loss: 7.0512 - val_accuracy: 0.4210
# Epoch 27/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.5605 - accuracy: 0.4201 - val_loss: 4.6272 - val_accuracy: 0.4210
# Epoch 28/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.7584 - accuracy: 0.4201 - val_loss: 3.9007 - val_accuracy: 0.4210
# Epoch 29/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.9871 - accuracy: 0.4201 - val_loss: 6.3408 - val_accuracy: 0.4210
# Epoch 30/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.6904 - accuracy: 0.4201 - val_loss: 5.0346 - val_accuracy: 0.4210
# Epoch 31/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.4963 - accuracy: 0.4201 - val_loss: 4.1098 - val_accuracy: 0.4210
# Epoch 32/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.1086 - accuracy: 0.4201 - val_loss: 5.7997 - val_accuracy: 0.4210
# Epoch 33/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.7775 - accuracy: 0.4201 - val_loss: 5.3280 - val_accuracy: 0.4210
# Epoch 34/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.2987 - accuracy: 0.4201 - val_loss: 4.3260 - val_accuracy: 0.4210
# Epoch 35/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.1897 - accuracy: 0.4201 - val_loss: 5.3323 - val_accuracy: 0.4210
# Epoch 36/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.8627 - accuracy: 0.4201 - val_loss: 5.4610 - val_accuracy: 0.4210
# Epoch 37/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.1648 - accuracy: 0.4201 - val_loss: 4.5685 - val_accuracy: 0.4210
# Epoch 38/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.2205 - accuracy: 0.4201 - val_loss: 5.0742 - val_accuracy: 0.4210
# Epoch 39/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.9371 - accuracy: 0.4201 - val_loss: 5.3985 - val_accuracy: 0.4210
# Epoch 40/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0893 - accuracy: 0.4201 - val_loss: 4.8286 - val_accuracy: 0.4210
# Epoch 41/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.2118 - accuracy: 0.4201 - val_loss: 5.0834 - val_accuracy: 0.4210
# Epoch 42/100
# 328/328 [==============================] - 1s 3ms/step - loss: 4.9969 - accuracy: 0.4201 - val_loss: 5.4062 - val_accuracy: 0.4210
# Epoch 43/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0560 - accuracy: 0.4201 - val_loss: 4.9379 - val_accuracy: 0.4210
# Epoch 44/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.1862 - accuracy: 0.4201 - val_loss: 4.9480 - val_accuracy: 0.4210
# Epoch 45/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0486 - accuracy: 0.4201 - val_loss: 5.2373 - val_accuracy: 0.4210
# Epoch 46/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0447 - accuracy: 0.4201 - val_loss: 5.1170 - val_accuracy: 0.4210
# Epoch 47/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.1530 - accuracy: 0.4201 - val_loss: 5.0600 - val_accuracy: 0.4210
# Epoch 48/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0756 - accuracy: 0.4201 - val_loss: 5.2272 - val_accuracy: 0.4210
# Epoch 49/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0483 - accuracy: 0.4201 - val_loss: 5.0447 - val_accuracy: 0.4210
# Epoch 50/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.1244 - accuracy: 0.4201 - val_loss: 4.9205 - val_accuracy: 0.4210
# Epoch 51/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0956 - accuracy: 0.4201 - val_loss: 5.0492 - val_accuracy: 0.4210
# Epoch 52/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0523 - accuracy: 0.4201 - val_loss: 5.1432 - val_accuracy: 0.4210
# Epoch 53/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.1139 - accuracy: 0.4201 - val_loss: 5.0048 - val_accuracy: 0.4210
# Epoch 54/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0991 - accuracy: 0.4201 - val_loss: 5.0520 - val_accuracy: 0.4210
# Epoch 55/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0629 - accuracy: 0.4201 - val_loss: 5.1625 - val_accuracy: 0.4210
# Epoch 56/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.1012 - accuracy: 0.4201 - val_loss: 5.0774 - val_accuracy: 0.4210
# Epoch 57/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.1049 - accuracy: 0.4201 - val_loss: 5.0488 - val_accuracy: 0.4210
# Epoch 58/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0672 - accuracy: 0.4201 - val_loss: 5.1484 - val_accuracy: 0.4210
# Epoch 59/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0932 - accuracy: 0.4201 - val_loss: 5.0518 - val_accuracy: 0.4210
# Epoch 60/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.1025 - accuracy: 0.4201 - val_loss: 5.0674 - val_accuracy: 0.4210
# Epoch 61/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0735 - accuracy: 0.4201 - val_loss: 5.2045 - val_accuracy: 0.4210
# Epoch 62/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0904 - accuracy: 0.4201 - val_loss: 5.0802 - val_accuracy: 0.4210
# Epoch 63/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0999 - accuracy: 0.4201 - val_loss: 5.1132 - val_accuracy: 0.4210
# Epoch 64/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0758 - accuracy: 0.4201 - val_loss: 5.1025 - val_accuracy: 0.4210
# Epoch 65/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0906 - accuracy: 0.4201 - val_loss: 5.0553 - val_accuracy: 0.4210
# Epoch 66/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0968 - accuracy: 0.4201 - val_loss: 5.1285 - val_accuracy: 0.4210
# Epoch 67/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0813 - accuracy: 0.4201 - val_loss: 5.2147 - val_accuracy: 0.4210
# Epoch 68/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0896 - accuracy: 0.4201 - val_loss: 5.0664 - val_accuracy: 0.4210
# Epoch 69/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0937 - accuracy: 0.4201 - val_loss: 5.0784 - val_accuracy: 0.4210
# Epoch 70/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0873 - accuracy: 0.4201 - val_loss: 5.1447 - val_accuracy: 0.4210
# Epoch 71/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0824 - accuracy: 0.4201 - val_loss: 5.0550 - val_accuracy: 0.4210
# Epoch 72/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0939 - accuracy: 0.4201 - val_loss: 5.1448 - val_accuracy: 0.4210
# Epoch 73/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0855 - accuracy: 0.4201 - val_loss: 5.0999 - val_accuracy: 0.4210
# Epoch 74/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0876 - accuracy: 0.4201 - val_loss: 5.0203 - val_accuracy: 0.4210
# Epoch 75/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0944 - accuracy: 0.4201 - val_loss: 5.1637 - val_accuracy: 0.4210
# Epoch 76/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0820 - accuracy: 0.4201 - val_loss: 5.1084 - val_accuracy: 0.4210
# Epoch 77/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0867 - accuracy: 0.4201 - val_loss: 5.1317 - val_accuracy: 0.4210
# Epoch 78/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0982 - accuracy: 0.4201 - val_loss: 5.0542 - val_accuracy: 0.4210
# Epoch 79/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0824 - accuracy: 0.4201 - val_loss: 5.1328 - val_accuracy: 0.4210
# Epoch 80/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0886 - accuracy: 0.4201 - val_loss: 5.0251 - val_accuracy: 0.4210
# Epoch 81/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0967 - accuracy: 0.4201 - val_loss: 5.1220 - val_accuracy: 0.4210
# Epoch 82/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0829 - accuracy: 0.4201 - val_loss: 5.1332 - val_accuracy: 0.4210
# Epoch 83/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0880 - accuracy: 0.4201 - val_loss: 5.0702 - val_accuracy: 0.4210
# Epoch 84/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0911 - accuracy: 0.4201 - val_loss: 5.0867 - val_accuracy: 0.4210
# Epoch 85/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0885 - accuracy: 0.4201 - val_loss: 5.0780 - val_accuracy: 0.4210
# Epoch 86/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0872 - accuracy: 0.4201 - val_loss: 5.0384 - val_accuracy: 0.4210
# Epoch 87/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0914 - accuracy: 0.4201 - val_loss: 5.1198 - val_accuracy: 0.4210
# Epoch 88/100
# 328/328 [==============================] - 1s 4ms/step - loss: 5.0834 - accuracy: 0.4201 - val_loss: 5.0295 - val_accuracy: 0.4210
# Epoch 89/100
# 328/328 [==============================] - 1s 4ms/step - loss: 5.0931 - accuracy: 0.4201 - val_loss: 5.0794 - val_accuracy: 0.4210
# Epoch 90/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0905 - accuracy: 0.4201 - val_loss: 5.0049 - val_accuracy: 0.4210
# Epoch 91/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0797 - accuracy: 0.4201 - val_loss: 5.1040 - val_accuracy: 0.4210
# Epoch 92/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0931 - accuracy: 0.4201 - val_loss: 5.1103 - val_accuracy: 0.4210
# Epoch 93/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0925 - accuracy: 0.4201 - val_loss: 5.0691 - val_accuracy: 0.4210
# Epoch 94/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0864 - accuracy: 0.4201 - val_loss: 5.1040 - val_accuracy: 0.4210
# Epoch 95/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0871 - accuracy: 0.4201 - val_loss: 5.0271 - val_accuracy: 0.4210
# Epoch 96/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0899 - accuracy: 0.4201 - val_loss: 5.1171 - val_accuracy: 0.4210
# Epoch 97/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0936 - accuracy: 0.4201 - val_loss: 5.0906 - val_accuracy: 0.4210
# Epoch 98/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0832 - accuracy: 0.4201 - val_loss: 5.1336 - val_accuracy: 0.4210
# Epoch 99/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0967 - accuracy: 0.4201 - val_loss: 5.1314 - val_accuracy: 0.4210
# Epoch 100/100
# 328/328 [==============================] - 1s 3ms/step - loss: 5.0814 - accuracy: 0.4201 - val_loss: 5.0834 - val_accuracy: 0.4210

# %%
# hyper parameters 3
b_size = 300
num_epochs = 50
model1 = NNModel([64, 32], train_X.shape[1])
moldel1_H = model1.train(train_X, train_Y, val_X, val_Y, num_epochs=num_epochs, b_size=b_size, optim=Adam(learning_rate=0.01))

avg_acc = sum(moldel1_H.history['val_accuracy']) / len(moldel1_H.history['val_accuracy'])
avg_loss = sum(moldel1_H.history['val_loss']) / len(moldel1_H.history['val_loss'])

if avg_acc > best_val_avg_acc:
    print("selected the trained model as best model")
    print("average val accuracy: " + str(avg_acc))
    print("average val loss: " + str(avg_loss))
    best_model = model1
    best_val_avg_acc = avg_acc
    best_val_avg_loss = avg_loss
elif avg_acc == best_val_avg_acc:
    if avg_loss < best_val_avg_loss:
        print("selected the trained model as best model")
        print("average val accuracy: " + str(avg_acc))
        print("average val loss: " + str(avg_loss))
        best_model = model1
        best_val_avg_acc = avg_acc
        best_val_avg_loss = avg_loss
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 64)                208064
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dense_8 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 210,177
# Trainable params: 210,177
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 110/110 [==============================] - 1s 6ms/step - loss: 1.1187 - accuracy: 0.4201 - val_loss: 0.6807 - val_accuracy: 0.4210
# Epoch 2/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6804 - accuracy: 0.4201 - val_loss: 0.6806 - val_accuracy: 0.4210
# Epoch 3/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.4201 - val_loss: 0.6807 - val_accuracy: 0.4210
# Epoch 4/50
# 110/110 [==============================] - 0s 5ms/step - loss: 0.6806 - accuracy: 0.4201 - val_loss: 0.6806 - val_accuracy: 0.4210
# Epoch 5/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6805 - accuracy: 0.4201 - val_loss: 0.6807 - val_accuracy: 0.4210
# Epoch 6/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6804 - accuracy: 0.4201 - val_loss: 0.6808 - val_accuracy: 0.4210
# Epoch 7/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6806 - accuracy: 0.4201 - val_loss: 0.6807 - val_accuracy: 0.4210
# Epoch 8/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6804 - accuracy: 0.4201 - val_loss: 0.6807 - val_accuracy: 0.4210
# Epoch 9/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6806 - accuracy: 0.4201 - val_loss: 0.6811 - val_accuracy: 0.4210
# Epoch 10/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6806 - accuracy: 0.4201 - val_loss: 0.6807 - val_accuracy: 0.4210
# Epoch 11/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6804 - accuracy: 0.4201 - val_loss: 0.6809 - val_accuracy: 0.4210
# Epoch 12/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6817 - accuracy: 0.4201 - val_loss: 0.6815 - val_accuracy: 0.4210
# Epoch 13/50
# 110/110 [==============================] - 0s 5ms/step - loss: 0.6905 - accuracy: 0.4201 - val_loss: 0.6868 - val_accuracy: 0.4210
# Epoch 14/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6861 - accuracy: 0.4201 - val_loss: 0.6862 - val_accuracy: 0.4210
# Epoch 15/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6863 - accuracy: 0.4201 - val_loss: 0.6870 - val_accuracy: 0.4210
# Epoch 16/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6865 - accuracy: 0.4201 - val_loss: 0.6876 - val_accuracy: 0.4210
# Epoch 17/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6866 - accuracy: 0.4201 - val_loss: 0.6868 - val_accuracy: 0.4210
# Epoch 18/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6873 - accuracy: 0.4201 - val_loss: 0.6880 - val_accuracy: 0.4210
# Epoch 19/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6867 - accuracy: 0.4201 - val_loss: 0.6881 - val_accuracy: 0.4210
# Epoch 20/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6855 - accuracy: 0.4201 - val_loss: 0.6851 - val_accuracy: 0.4210
# Epoch 21/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6882 - accuracy: 0.4201 - val_loss: 0.6895 - val_accuracy: 0.4210
# Epoch 22/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6880 - accuracy: 0.4201 - val_loss: 0.6873 - val_accuracy: 0.4210
# Epoch 23/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6868 - accuracy: 0.4201 - val_loss: 0.6870 - val_accuracy: 0.4210
# Epoch 24/50
# 110/110 [==============================] - 0s 5ms/step - loss: 0.6876 - accuracy: 0.4201 - val_loss: 0.6879 - val_accuracy: 0.4210
# Epoch 25/50
# 110/110 [==============================] - 0s 5ms/step - loss: 0.6875 - accuracy: 0.4201 - val_loss: 0.6877 - val_accuracy: 0.4210
# Epoch 26/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6873 - accuracy: 0.4201 - val_loss: 0.6872 - val_accuracy: 0.4210
# Epoch 27/50
# 110/110 [==============================] - 0s 5ms/step - loss: 0.6875 - accuracy: 0.4201 - val_loss: 0.6881 - val_accuracy: 0.4210
# Epoch 28/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6901 - accuracy: 0.4201 - val_loss: 0.6895 - val_accuracy: 0.4210
# Epoch 29/50
# 110/110 [==============================] - 0s 5ms/step - loss: 0.6885 - accuracy: 0.4201 - val_loss: 0.6880 - val_accuracy: 0.4210
# Epoch 30/50
# 110/110 [==============================] - 0s 5ms/step - loss: 0.6874 - accuracy: 0.4201 - val_loss: 0.6875 - val_accuracy: 0.4210
# Epoch 31/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6872 - accuracy: 0.4201 - val_loss: 0.6872 - val_accuracy: 0.4210
# Epoch 32/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6876 - accuracy: 0.4201 - val_loss: 0.6876 - val_accuracy: 0.4210
# Epoch 33/50
# 110/110 [==============================] - 0s 5ms/step - loss: 0.6874 - accuracy: 0.4201 - val_loss: 0.6875 - val_accuracy: 0.4210
# Epoch 34/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6894 - accuracy: 0.4201 - val_loss: 0.6893 - val_accuracy: 0.4210
# Epoch 35/50
# 110/110 [==============================] - 0s 5ms/step - loss: 0.6885 - accuracy: 0.4201 - val_loss: 0.6888 - val_accuracy: 0.4210
# Epoch 36/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.4201 - val_loss: 0.6879 - val_accuracy: 0.4210
# Epoch 37/50
# 110/110 [==============================] - 0s 5ms/step - loss: 0.6867 - accuracy: 0.4201 - val_loss: 0.6863 - val_accuracy: 0.4210
# Epoch 38/50
# 110/110 [==============================] - 0s 5ms/step - loss: 0.6872 - accuracy: 0.4201 - val_loss: 0.6904 - val_accuracy: 0.4210
# Epoch 39/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6886 - accuracy: 0.4201 - val_loss: 0.6902 - val_accuracy: 0.4210
# Epoch 40/50
# 110/110 [==============================] - 0s 5ms/step - loss: 0.6890 - accuracy: 0.4201 - val_loss: 0.6886 - val_accuracy: 0.4210
# Epoch 41/50
# 110/110 [==============================] - 0s 5ms/step - loss: 0.6877 - accuracy: 0.4201 - val_loss: 0.6882 - val_accuracy: 0.4210
# Epoch 42/50
# 110/110 [==============================] - 0s 5ms/step - loss: 0.6879 - accuracy: 0.4201 - val_loss: 0.6880 - val_accuracy: 0.4210
# Epoch 43/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6870 - accuracy: 0.4201 - val_loss: 0.6870 - val_accuracy: 0.4210
# Epoch 44/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6879 - accuracy: 0.4201 - val_loss: 0.6894 - val_accuracy: 0.4210
# Epoch 45/50
# 110/110 [==============================] - 0s 5ms/step - loss: 0.6888 - accuracy: 0.4201 - val_loss: 0.6885 - val_accuracy: 0.4210
# Epoch 46/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6879 - accuracy: 0.4201 - val_loss: 0.6882 - val_accuracy: 0.4210
# Epoch 47/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6874 - accuracy: 0.4201 - val_loss: 0.6878 - val_accuracy: 0.4210
# Epoch 48/50
# 110/110 [==============================] - 0s 5ms/step - loss: 0.6875 - accuracy: 0.4201 - val_loss: 0.6875 - val_accuracy: 0.4210
# Epoch 49/50
# 110/110 [==============================] - 0s 5ms/step - loss: 0.6880 - accuracy: 0.4201 - val_loss: 0.6885 - val_accuracy: 0.4210
# Epoch 50/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6881 - accuracy: 0.4201 - val_loss: 0.6881 - val_accuracy: 0.4210
# selected the trained model as best model
# average val accuracy: 0.42095237970352173
# average val loss: 0.6861959981918335

# %%
def accuracy(y, y_hat):
    """
    Citation: taken from lecture notebook
    
    Measure the accuracy of our model, print the results.
    Parameters:
        y (array): true labels
        y_hat (array): model estimates
    Returns:
        None
    """
    count = 0
    for i in range(len(y)):
        guess = 1 if y_hat[i] > 0.5 else 0
        if guess == y[i]:
            count += 1
    print("Accuracy:", round((count / y.shape[0]) * 100, 2))

# %%
pred = best_model.test_batch(test_X)
accuracy(test_Y, pred.reshape(test_Y.shape))
# Out:
# 121/121 [==============================] - 0s 692us/step
# Accuracy: 41.89

# %%
# create summaries for the test set using the trained model.
# original test data

inf_file = prepare_bbc_data.out_test_file
inf_df = pd.read_csv(inf_file)

out_headers = {'article': [],
               'original_summary': [],
               'model_summary': [],
              }

# summaries generated from the model will be written to this file.
out_file = 'NN_results.csv'

out_df = pd.DataFrame(out_headers)

inf_start = time.time()
for i in range(len(inf_df)):
    art_txt = inf_df.at[i, 'article'].strip()
    # from raw article text, create sentences. 
    # prepped sent has the preprocessed sentence while orig_sent has the actual sentence
    orig_sent, prepped_sent = create_inf_sents(art_txt)

    summary = []
    # loops to estimate if the sentence is a highlight or not 
    # If it is a highlight, appends the original sentence to the summary string.
    for j, sent in enumerate(prepped_sent):
        inf_X = featurize_X_from_text(sent, wv_from_text)
        pred = best_model.test_single(inf_X)
        if pred[0] > 0.5:
            summary.append(orig_sent[j])
    out_df.at[i, 'article'] = art_txt
    out_df.at[i, 'original_summary'] = inf_df.at[i, 'summary'].strip()
    if len(summary) == 0:
        out_df.at[i, 'model_summary'] = "__BLANK__"
    else:
        out_df.at[i, 'model_summary'] = " ".join(summary)

out_df.to_csv(out_file, index=False)
print("inference completed for the test set\nTime taken: " + str(time.time()-inf_start))
# Out:
# inference completed for the test set
# Time taken: 4.929999589920044
