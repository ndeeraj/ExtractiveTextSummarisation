# %%
import numpy as np
import os.path
from gensim.models import KeyedVectors
import time
import string
import train_embeddings_bbc
import preprocessing_bbc
import prepare_bbc_data
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.initializers import RandomNormal
from keras.regularizers import L2
from utils import create_inf_sents, featurize_X_from_text, featurize_embed_from_df

# %%
# load preprocessed files
train_file = preprocessing_bbc.cleaned_train_f
test_file = preprocessing_bbc.cleaned_test_f
val_file = preprocessing_bbc.cleaned_val_f

wv_from_text = train_embeddings_bbc.load_embeddings(train_embeddings_bbc.embedding_file)

train_data = pd.read_csv(train_file)
test_data = pd.read_csv(test_file)
val_data = pd.read_csv(val_file)

# %%
EMBED_SIZE = train_embeddings_bbc.EMBEDDINGS_SIZE

MAX_WORD_SIZE = preprocessing_bbc.MAX_THRESH

# %%
# initialize features with zeros
train_X = np.zeros((len(train_data), (EMBED_SIZE * MAX_WORD_SIZE)))
test_X = np.zeros((len(test_data), (EMBED_SIZE * MAX_WORD_SIZE)))
val_X = np.zeros((len(val_data), (EMBED_SIZE * MAX_WORD_SIZE)))

train_Y = np.zeros((len(train_data), 1))
test_Y = np.zeros((len(test_data), 1))
val_Y = np.zeros((len(val_data), 1))

# %%
# fill the features based on the learned embeddings
featurize_embed_from_df(train_data, train_X, train_Y, wv_from_text)
featurize_embed_from_df(test_data, test_X, test_Y, wv_from_text)
featurize_embed_from_df(val_data, val_X, val_Y, wv_from_text)

# %%
print("Shape of train X:")
print(train_X.shape)
print("Shape of train Y:")
print(train_Y.shape)

print("Shape of test X:")
print(test_X.shape)
print("Shape of test Y:")
print(test_Y.shape)

print("Shape of val X:")
print(test_X.shape)
print("Shape of val Y:")
print(test_Y.shape)
# Out:
# Shape of train X:
# (32722, 3250)
# Shape of train Y:
# (32722, 1)
# Shape of test X:
# (3872, 3250)
# Shape of test Y:
# (3872, 1)
# Shape of val X:
# (3872, 3250)
# Shape of val Y:
# (3872, 1)

# %%
# Define the model architecture using Keras Sequential API
class NNModel:
    '''
    Initizializes a model with number of hidden layers as specified in the hidden_dim list
    with activation functions as softmax at the final layer and relu for other layers.
    
    Uses Adam optimizer and binary cross entropy loss.
    '''
    def __init__(self, hidden_dim, feature_dim):
        '''
        Parameters:
            hidden_dim (list): each item specified the number of nodes in each hidden layer
            feature_dim (int): number of features in a sample
        '''
        
        if feature_dim <= 0 or feature_dim is None:
            raise Exception("feature dim mut be specified.")
        output_size = 1
        model = Sequential()
        for dim in hidden_dim:
            model.add(Dense(dim, input_dim=feature_dim, 
                            activation='relu',
                            kernel_initializer=RandomNormal(stddev=0.01),
                            kernel_regularizer=L2(0.5),
                           ))
    
        model.add(Dense(output_size, 
                        activation="softmax",
                        kernel_initializer=RandomNormal(stddev=0.01),
                        kernel_regularizer=L2(0.5),
                       ))
        self.model = model
        print(model.summary())
    
    def train(self, trainX, trainY, valX, valY, num_epochs=10, b_size=200, optim=None):
        '''
        trains the model with the provided parameters
        '''
        model = self.model
        if optim is None:
            optim = Adam(learning_rate=0.2)
        model.compile(loss="binary_crossentropy", optimizer=optim, metrics=["accuracy"])
        history = model.fit(trainX, trainY, batch_size=b_size, epochs=num_epochs, verbose=1, validation_data=(valX, valY), shuffle=True, validation_batch_size=b_size)
        return history
    
    def test_batch(self, testX):
        '''
        gets predictions for a batch of results.
        '''
        model = self.model
        predictions = model.predict(testX)
        return predictions
    
    def test_single(self, testX):
        '''
        gets prediction for a single instance
        '''
        model = self.model
        predictions = model([np.array(testX).reshape(1,-1)], training=False).numpy()
        return predictions

# %%
b_size = 300
num_epochs = 50
model1 = NNModel([64, 32], train_X.shape[1])
moldel1_H = model1.train(train_X, train_Y, val_X, val_Y, num_epochs=num_epochs, b_size=b_size)
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_49 (Dense)            (None, 64)                208064
#
#  dense_50 (Dense)            (None, 32)                2080
#
#  dense_51 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 210,177
# Trainable params: 210,177
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 110/110 [==============================] - 1s 6ms/step - loss: 149.2052 - accuracy: 0.4201 - val_loss: 0.7041 - val_accuracy: 0.4210
# Epoch 2/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6849 - accuracy: 0.4201 - val_loss: 0.6812 - val_accuracy: 0.4210
# Epoch 3/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6820 - accuracy: 0.4201 - val_loss: 0.6812 - val_accuracy: 0.4210
# Epoch 4/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6822 - accuracy: 0.4201 - val_loss: 0.6808 - val_accuracy: 0.4210
# Epoch 5/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6811 - accuracy: 0.4201 - val_loss: 0.6816 - val_accuracy: 0.4210
# Epoch 6/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6811 - accuracy: 0.4201 - val_loss: 0.6812 - val_accuracy: 0.4210
# Epoch 7/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6812 - accuracy: 0.4201 - val_loss: 0.6827 - val_accuracy: 0.4210
# Epoch 8/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6809 - accuracy: 0.4201 - val_loss: 0.6810 - val_accuracy: 0.4210
# Epoch 9/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6830 - accuracy: 0.4201 - val_loss: 0.6850 - val_accuracy: 0.4210
# Epoch 10/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6824 - accuracy: 0.4201 - val_loss: 0.6818 - val_accuracy: 0.4210
# Epoch 11/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6832 - accuracy: 0.4201 - val_loss: 0.6860 - val_accuracy: 0.4210
# Epoch 12/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6830 - accuracy: 0.4201 - val_loss: 0.6864 - val_accuracy: 0.4210
# Epoch 13/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6852 - accuracy: 0.4201 - val_loss: 0.6827 - val_accuracy: 0.4210
# Epoch 14/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6852 - accuracy: 0.4201 - val_loss: 0.6880 - val_accuracy: 0.4210
# Epoch 15/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.6870 - accuracy: 0.4201 - val_loss: 0.6900 - val_accuracy: 0.4210
# Epoch 16/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.7029 - accuracy: 0.4201 - val_loss: 0.7212 - val_accuracy: 0.4210
# Epoch 17/50
# 110/110 [==============================] - 0s 4ms/step - loss: 0.8762 - accuracy: 0.4201 - val_loss: 1.2266 - val_accuracy: 0.4210
# Epoch 18/50
# 110/110 [==============================] - 0s 4ms/step - loss: 5.6178 - accuracy: 0.4201 - val_loss: 7.6577 - val_accuracy: 0.4210
# Epoch 19/50
# 110/110 [==============================] - 0s 4ms/step - loss: 9.8950 - accuracy: 0.4201 - val_loss: 10.6854 - val_accuracy: 0.4210
# Epoch 20/50
# 110/110 [==============================] - 0s 4ms/step - loss: 8.8926 - accuracy: 0.4201 - val_loss: 1.4291 - val_accuracy: 0.4210
# Epoch 21/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.5423 - accuracy: 0.4201 - val_loss: 1.5974 - val_accuracy: 0.4210
# Epoch 22/50
# 110/110 [==============================] - 0s 4ms/step - loss: 1.7085 - accuracy: 0.4201 - val_loss: 1.9060 - val_accuracy: 0.4210
# Epoch 23/50
# 110/110 [==============================] - 0s 4ms/step - loss: 2.1801 - accuracy: 0.4201 - val_loss: 2.6855 - val_accuracy: 0.4210
# Epoch 24/50
# 110/110 [==============================] - 0s 4ms/step - loss: 2.6882 - accuracy: 0.4201 - val_loss: 2.6247 - val_accuracy: 0.4210
# Epoch 25/50
# 110/110 [==============================] - 0s 4ms/step - loss: 3.5847 - accuracy: 0.4201 - val_loss: 2.1208 - val_accuracy: 0.4210
# Epoch 26/50
# 110/110 [==============================] - 0s 4ms/step - loss: 2.6804 - accuracy: 0.4201 - val_loss: 4.7074 - val_accuracy: 0.4210
# Epoch 27/50
# 110/110 [==============================] - 0s 4ms/step - loss: 2.7568 - accuracy: 0.4201 - val_loss: 2.7170 - val_accuracy: 0.4210
# Epoch 28/50
# 110/110 [==============================] - 0s 4ms/step - loss: 3.7204 - accuracy: 0.4201 - val_loss: 5.1994 - val_accuracy: 0.4210
# Epoch 29/50
# 110/110 [==============================] - 0s 4ms/step - loss: 9.3906 - accuracy: 0.4201 - val_loss: 9.6186 - val_accuracy: 0.4210
# Epoch 30/50
# 110/110 [==============================] - 0s 4ms/step - loss: 6.6818 - accuracy: 0.4201 - val_loss: 2.3960 - val_accuracy: 0.4210
# Epoch 31/50
# 110/110 [==============================] - 0s 4ms/step - loss: 2.5027 - accuracy: 0.4201 - val_loss: 2.7038 - val_accuracy: 0.4210
# Epoch 32/50
# 110/110 [==============================] - 0s 4ms/step - loss: 2.7184 - accuracy: 0.4201 - val_loss: 3.1065 - val_accuracy: 0.4210
# Epoch 33/50
# 110/110 [==============================] - 0s 4ms/step - loss: 2.8006 - accuracy: 0.4201 - val_loss: 2.2925 - val_accuracy: 0.4210
# Epoch 34/50
# 110/110 [==============================] - 0s 4ms/step - loss: 2.3247 - accuracy: 0.4201 - val_loss: 2.4477 - val_accuracy: 0.4210
# Epoch 35/50
# 110/110 [==============================] - 0s 5ms/step - loss: 2.8957 - accuracy: 0.4201 - val_loss: 3.6012 - val_accuracy: 0.4210
# Epoch 36/50
# 110/110 [==============================] - 0s 4ms/step - loss: 4.5460 - accuracy: 0.4201 - val_loss: 6.2453 - val_accuracy: 0.4210
# Epoch 37/50
# 110/110 [==============================] - 0s 4ms/step - loss: 7.2228 - accuracy: 0.4201 - val_loss: 7.0167 - val_accuracy: 0.4210
# Epoch 38/50
# 110/110 [==============================] - 0s 4ms/step - loss: 3.3573 - accuracy: 0.4201 - val_loss: 2.3992 - val_accuracy: 0.4210
# Epoch 39/50
# 110/110 [==============================] - 0s 4ms/step - loss: 2.4256 - accuracy: 0.4201 - val_loss: 2.4805 - val_accuracy: 0.4210
# Epoch 40/50
# 110/110 [==============================] - 0s 4ms/step - loss: 2.3871 - accuracy: 0.4201 - val_loss: 2.2819 - val_accuracy: 0.4210
# Epoch 41/50
# 110/110 [==============================] - 0s 4ms/step - loss: 2.3462 - accuracy: 0.4201 - val_loss: 2.5805 - val_accuracy: 0.4210
# Epoch 42/50
# 110/110 [==============================] - 0s 4ms/step - loss: 3.1492 - accuracy: 0.4201 - val_loss: 4.0161 - val_accuracy: 0.4210
# Epoch 43/50
# 110/110 [==============================] - 0s 4ms/step - loss: 5.7110 - accuracy: 0.4201 - val_loss: 6.6821 - val_accuracy: 0.4210
# Epoch 44/50
# 110/110 [==============================] - 0s 4ms/step - loss: 4.9122 - accuracy: 0.4201 - val_loss: 2.4966 - val_accuracy: 0.4210
# Epoch 45/50
# 110/110 [==============================] - 0s 4ms/step - loss: 2.2244 - accuracy: 0.4201 - val_loss: 2.1348 - val_accuracy: 0.4210
# Epoch 46/50
# 110/110 [==============================] - 0s 4ms/step - loss: 2.2159 - accuracy: 0.4201 - val_loss: 2.2315 - val_accuracy: 0.4210
# Epoch 47/50
# 110/110 [==============================] - 0s 4ms/step - loss: 2.4514 - accuracy: 0.4201 - val_loss: 3.0022 - val_accuracy: 0.4210
# Epoch 48/50
# 110/110 [==============================] - 0s 4ms/step - loss: 3.5960 - accuracy: 0.4201 - val_loss: 4.8074 - val_accuracy: 0.4210
# Epoch 49/50
# 110/110 [==============================] - 0s 4ms/step - loss: 5.6827 - accuracy: 0.4201 - val_loss: 5.4509 - val_accuracy: 0.4210
# Epoch 50/50
# 110/110 [==============================] - 0s 4ms/step - loss: 3.3705 - accuracy: 0.4201 - val_loss: 2.3455 - val_accuracy: 0.4210

# %%
def accuracy(y, y_hat):
    """
    Citation: taken from lecture notebook
    
    Measure the accuracy of our model, print the results.
    Parameters:
        y (array): true labels
        y_hat (array): model estimates
    Returns:
        None
    """
    count = 0
    for i in range(len(y)):
        guess = 1 if y_hat[i] > 0.5 else 0
        if guess == y[i]:
            count += 1
    print("Accuracy:", round((count / y.shape[0]) * 100, 2))

# %%
pred = model1.test_batch(test_X)
accuracy(test_Y, pred.reshape(test_Y.shape))
# Out:
# 121/121 [==============================] - 0s 767us/step
# Accuracy: 41.89

# %%
# create summaries for the test set using the trained model.
# original test data

inf_file = prepare_bbc_data.out_test_file
inf_df = pd.read_csv(inf_file)

out_headers = {'article': [],
               'original_summary': [],
               'model_summary': [],
              }

# summaries generated from the model will be written to this file.
out_file = 'NN_results.csv'

out_df = pd.DataFrame(out_headers)

inf_start = time.time()
for i in range(len(inf_df)):
    art_txt = inf_df.at[i, 'article'].strip()
    # from raw article text, create sentences. 
    # prepped sent has the preprocessed sentence while orig_sent has the actual sentence
    orig_sent, prepped_sent = create_inf_sents(art_txt)

    summary = []
    # loops to estimate if the sentence is a highlight or not 
    # If it is a highlight, appends the original sentence to the summary string.
    for j, sent in enumerate(prepped_sent):
        inf_X = featurize_X_from_text(sent, wv_from_text)
        pred = model1.test_single(inf_X)
        if pred[0] > 0.5:
            summary.append(orig_sent[j])
    out_df.at[i, 'article'] = art_txt
    out_df.at[i, 'original_summary'] = inf_df.at[i, 'summary'].strip()
    if len(summary) == 0:
        out_df.at[i, 'model_summary'] = "__BLANK__"
    else:
        out_df.at[i, 'model_summary'] = " ".join(summary)

out_df.to_csv(out_file, index=False)
print("inference completed for the test set\nTime taken: " + str(time.time()-inf_start))
# Out:
# inference completed for the test set
# Time taken: 5.384002447128296
